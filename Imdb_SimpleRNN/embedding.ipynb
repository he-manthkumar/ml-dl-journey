# %%
# Install the tensorflow package
# %pip install tensorflow

from tensorflow.keras.preprocessing.text import one_hot
# Out:
# Requirement already satisfied: tensorflow in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.25.5)
# Requirement already satisfied: setuptools in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.37.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\hemanth kumar\onedrive\desktop\learning\rnn\venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING:tensorflow:From c:\Users\Hemanth Kumar\OneDrive\Desktop\Learning\RNN\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
sent=['the glass of milk',
      'the glass of juice',
      'the cup of tea',
      'I am a good boy',
      'I am a good developer',
      'understand the meaning of words',
      'your videos are good']

# %%
## Vocabulary size = 10000
voc_size=10000

# %%
# One hot representation
onehot_repr=[one_hot(words,voc_size)for words in sent]
print(onehot_repr)
# Out:
# [[2780, 9725, 2562, 3082], [2780, 9725, 2562, 2756], [2780, 1327, 2562, 6770], [4672, 1223, 4943, 6239, 8847], [4672, 1223, 4943, 6239, 4350], [8428, 2780, 5650, 2562, 4091], [2393, 7954, 249, 6239]]

# %%
## word embedding representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
sent_length=8
embeded_docs=pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
print(embeded_docs)
# Out:
# [[   0    0    0    0 2780 9725 2562 3082]
#  [   0    0    0    0 2780 9725 2562 2756]
#  [   0    0    0    0 2780 1327 2562 6770]
#  [   0    0    0 4672 1223 4943 6239 8847]
#  [   0    0    0 4672 1223 4943 6239 4350]
#  [   0    0    0 8428 2780 5650 2562 4091]
#  [   0    0    0    0 2393 7954  249 6239]]

# %%
#features_dimension
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From c:\Users\Hemanth Kumar\OneDrive\Desktop\Learning\RNN\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Hemanth Kumar\OneDrive\Desktop\Learning\RNN\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
##for hyperparameter tuning
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embeded_docs)
# Out:
# 1/1 [==============================] - 0s 50ms/step
# array([[[-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [ 0.00848986, -0.03752672,  0.02563628, -0.04074721,
#          -0.03517778, -0.00323843, -0.03149166, -0.02323294,
#          -0.02565032, -0.03802376],
#         [ 0.02910402, -0.02942498,  0.01251638,  0.03667006,
#          -0.03403091, -0.00269458,  0.02325735, -0.02064863,
#           0.04491288,  0.02506304],
#         [-0.00852467,  0.03291405,  0.01913768,  0.01174616,
#          -0.01242627,  0.04750672,  0.03386471,  0.00508203,
#           0.02429384, -0.03577572],
#         [ 0.03041269,  0.01578018,  0.04705144,  0.00441663,
#          -0.03440773, -0.03417419, -0.00935494, -0.00980542,
#           0.04241968, -0.01726085]],
#
#        [[-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [ 0.00848986, -0.03752672,  0.02563628, -0.04074721,
#          -0.03517778, -0.00323843, -0.03149166, -0.02323294,
#          -0.02565032, -0.03802376],
#         [ 0.02910402, -0.02942498,  0.01251638,  0.03667006,
#          -0.03403091, -0.00269458,  0.02325735, -0.02064863,
#           0.04491288,  0.02506304],
#         [-0.00852467,  0.03291405,  0.01913768,  0.01174616,
#          -0.01242627,  0.04750672,  0.03386471,  0.00508203,
#           0.02429384, -0.03577572],
#         [-0.0315189 ,  0.00744997, -0.01832233,  0.04797857,
#           0.00287915,  0.02352409, -0.03837843, -0.04711276,
#           0.01650205, -0.00010214]],
#
#        [[-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [ 0.00848986, -0.03752672,  0.02563628, -0.04074721,
#          -0.03517778, -0.00323843, -0.03149166, -0.02323294,
#          -0.02565032, -0.03802376],
#         [ 0.03846001,  0.02775696, -0.0283411 ,  0.02912377,
#           0.0493249 , -0.03291056,  0.03112122,  0.00313907,
#          -0.00153024,  0.00201362],
#         [-0.00852467,  0.03291405,  0.01913768,  0.01174616,
#          -0.01242627,  0.04750672,  0.03386471,  0.00508203,
#           0.02429384, -0.03577572],
#         [-0.00900805, -0.00146757, -0.03723704, -0.03098493,
#          -0.04848614, -0.04276078, -0.01465676,  0.02427937,
#           0.04877099, -0.02110981]],
#
#        [[-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.00712614,  0.01546874, -0.00246693, -0.031799  ,
#           0.03285975,  0.03414548, -0.02072969, -0.04018663,
#          -0.01279888,  0.02171885],
#         [ 0.00267928,  0.03505952,  0.01831515, -0.03504945,
#           0.01171944, -0.04499647,  0.03200937,  0.02943495,
#           0.0065973 ,  0.03082735],
#         [ 0.00540494, -0.03556033, -0.00598632, -0.04204943,
#          -0.03119124, -0.02339258, -0.01933037, -0.015962  ,
#          -0.0132228 , -0.01662106],
#         [-0.02817051,  0.00318275,  0.00468714,  0.0280943 ,
#          -0.02962366, -0.00201749, -0.00091457,  0.0476809 ,
#           0.01793318,  0.0226222 ],
#         [-0.03346481,  0.01163744, -0.02793317,  0.04093942,
#           0.01446051, -0.02256243,  0.00848824,  0.03322666,
#          -0.04403627,  0.03367437]],
#
#        [[-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.00712614,  0.01546874, -0.00246693, -0.031799  ,
#           0.03285975,  0.03414548, -0.02072969, -0.04018663,
#          -0.01279888,  0.02171885],
#         [ 0.00267928,  0.03505952,  0.01831515, -0.03504945,
#           0.01171944, -0.04499647,  0.03200937,  0.02943495,
#           0.0065973 ,  0.03082735],
#         [ 0.00540494, -0.03556033, -0.00598632, -0.04204943,
#          -0.03119124, -0.02339258, -0.01933037, -0.015962  ,
#          -0.0132228 , -0.01662106],
#         [-0.02817051,  0.00318275,  0.00468714,  0.0280943 ,
#          -0.02962366, -0.00201749, -0.00091457,  0.0476809 ,
#           0.01793318,  0.0226222 ],
#         [-0.00674421,  0.04963963, -0.00690629, -0.02357852,
#          -0.01984936, -0.03922942,  0.03606853, -0.03312631,
#          -0.00553502, -0.01931642]],
#
#        [[-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.02881868, -0.03721658,  0.04911281, -0.01306945,
#          -0.00587397,  0.04322426,  0.01462246, -0.04152505,
#          -0.02469738,  0.00658779],
#         [ 0.00848986, -0.03752672,  0.02563628, -0.04074721,
#          -0.03517778, -0.00323843, -0.03149166, -0.02323294,
#          -0.02565032, -0.03802376],
#         [-0.01126113,  0.0214613 , -0.00339954, -0.03016098,
#          -0.00641797,  0.00078942, -0.04855343,  0.02414462,
#          -0.01434076, -0.03786994],
#         [-0.00852467,  0.03291405,  0.01913768,  0.01174616,
#          -0.01242627,  0.04750672,  0.03386471,  0.00508203,
#           0.02429384, -0.03577572],
#         [-0.00123726, -0.01641463, -0.00676905,  0.04844138,
#          -0.0286419 , -0.00385299, -0.04660985,  0.0187086 ,
#          -0.02559236,  0.01329274]],
#
#        [[-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [-0.04786874,  0.0348686 ,  0.03295952, -0.02398058,
#           0.01481116, -0.03658783, -0.00044023,  0.04247187,
#          -0.03654295, -0.04498779],
#         [ 0.03266368, -0.02332299, -0.03386406, -0.03094287,
#          -0.03696345,  0.0297732 , -0.02245008,  0.00476216,
#          -0.00017784, -0.0202523 ],
#         [ 0.00792365, -0.00521898,  0.04746484,  0.03509519,
#          -0.01609887, -0.01270377,  0.02617567, -0.02570194,
#           0.02115739,  0.03847371],
#         [-0.025612  , -0.03020401, -0.03881925, -0.04901357,
#          -0.00838261,  0.0064294 ,  0.02073822,  0.00909058,
#           0.00619308, -0.02343247],
#         [-0.02817051,  0.00318275,  0.00468714,  0.0280943 ,
#          -0.02962366, -0.00201749, -0.00091457,  0.0476809 ,
#           0.01793318,  0.0226222 ]]], dtype=float32)
